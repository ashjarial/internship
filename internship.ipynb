# %%
import pandas as pd #import pandas library to read the data given in csv file

# %%
data1=pd.read_csv('C:/Users/ASUS/Documents/Raw_Skills_Dataset.csv')

# %%
data2=pd.read_csv('C:/Users/ASUS/Documents/Example_Technical_Skills.csv')

# %%
l=[]
for i in data2['Technology Skills']:    #appending the list of technical skill in the l list
    l.append(i)

# %%
l2=[]
for i in data1['RAW DATA']:
    for j in l:                        #checking the techical skill if it present in data1 and if present then appending in l2
        if i==j:
            l2.append(i)
            break

# %%
for i in  l2:
    print(i)                          #here i get same skill multiple time
# Out:
# MySQL
# SCSS
# EAC
# DevOps
# DevOps
# OpenShift
# GitHub
# MySQL
# GitHub
# GitHub
# MySQL
# GitHub
# MySQL
# NetSuite
# NetSuite
# GitHub
# Bitbucket
# GitHub
# Bitbucket
# GitHub
# Bitbucket
# Ethereum
# Kotlin
# Kotlin
# GitHub
# Kotlin
# Kotlin
# Kotlin
# Kotlin
# Kotlin
# Kotlin
# Kotlin
# MySQL
# Bash
# Bash
# GitHub
# Bash
# Ethereum
# Ethereum
# Ethereum
# Ethereum
# Ethereum
# Ethereum
# GitHub
# Bitbucket
# MySQL
# SCSS
# DevOps
# FTP
# MySQL
# DevOps
# DevOps
# MySQL
# OneStream
# DevOps
# DevOps
# Bash
# GitHub
# MySQL
# DevOps
# MySQL
# DevOps
# GitHub
# MySQL
# DevOps
# DevOps
# MySQL
# Consul
# OpenShift
# DevOps
# MySQL
# DevOps
# MySQL
# DevOps
# DevOps
# DevOps
# DevOps
# DevOps
# DevOps
# DevOps
# DevOps
# GitHub
# OpenShift
# OpenShift
# DevOps
# GitHub
# Force.com
# MySQL
# Kotlin
# Kotlin
# GitHub
# MySQL
# DevOps
# Kotlin
# Amazon Lambda
# GitHub
# Radius
# Bash
# MySQL
# Gulp
# MySQL
# Guidewire PolicyCenter
# DevOps
# Consul
# Kotlin
# Kotlin
# Kotlin
# ...

# %%
set1=set()                                
for i in l2:                         # so i made set which take only unique values in it
    set1.add(i)

# %%
print(set1)
# Out:
# {'MySQL', 'DevOps', 'FTP', 'Katalon', 'Amazon Lambda', 'Gulp', 'PostGIS', 'SAS JMP', 'Radius', 'Kotlin', 'SCSS', 'SAP Analytics Cloud', 'OpenShift', 'Force.com', 'EAC', 'Ethereum', 'OneStream', 'Octopus Deploy', 'NuGet', 'Bitbucket', 'Apache Oozie', 'ActiveMQ', 'Adobe Photoshop', 'GitHub', 'NetSuite', 'Bash', 'SAS Base', 'Phantom', 'SAP Lumira', 'SAS Enterprise Guide', 'Guidewire PolicyCenter', 'Microsoft Azure Networking', 'Magento', 'DRM', 'Eclipse', 'Consul'}

# %%
##so these are the technical skill which one should possess to add in the abanda team
{'MySQL', 'DevOps', 'FTP', 'Katalon', 'Amazon Lambda', 'Gulp', 'PostGIS', 'SAS JMP', 'Radius', 'Kotlin', 'SCSS', 'SAP Analytics Cloud', 'OpenShift', 'Force.com', 'EAC', 'Ethereum', 'OneStream', 'Octopus Deploy', 'NuGet', 'Bitbucket', 'Apache Oozie', 'ActiveMQ', 'Adobe Photoshop', 'GitHub', 'NetSuite', 'Bash', 'SAS Base', 'Phantom', 'SAP Lumira', 'SAS Enterprise Guide', 'Guidewire PolicyCenter', 'Microsoft Azure Networking', 'Magento', 'DRM', 'Eclipse', 'Consul'}
